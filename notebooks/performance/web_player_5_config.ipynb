# %%
audio = Audio.objects.last()
path = reverse("cast:api:audio_podlove_detail", kwargs={"pk": audio.pk, "post_id": 1})
url = f"http://localhost:8000{path}"
print(url)
# Out:
# http://localhost:8000/blogs/api/audios/podlove/2/post/1/

# %%
audio.episodes.all()
# Out:
# <PageQuerySet []>

# %%
audio.get_podlove_url(1)
# Out:
# '/blogs/api/audios/podlove/2/post/1/'

# %%
path = reverse("cast:api:player_config")
url = F"http://localhost:8000{path}"
print(url)
# Out:
# http://localhost:8000/blogs/api/audios/player_config/

# %%
dir(audio)
# Out:
# ['DoesNotExist',
#  'Meta',
#  'MultipleObjectsReturned',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_column_name_clashes',
#  '_check_constraints',
#  '_check_db_table_comment',
#  '_check_default_pk',
#  '_check_field_name_clashes',
#  '_check_fields',
#  '_check_id_field',
#  '_check_index_together',
#  '_check_indexes',
#  '_check_local_fields',
#  '_check_long_column_names',
#  '_check_m2m_through_same_relationship',
#  '_check_managers',
#  '_check_model',
#  '_check_model_name_db_lookup_clashes',
#  '_check_ordering',
# ...

# %%
podcast = audio.post_set.first().blog.specific

# %%
podcast.episode_set.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 podcast.episode_set.all()
#
# AttributeError: 'Podcast' object has no attribute 'episode_set'

# %%
podcast.poster
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 podcast.poster
#
# AttributeError: 'Podcast' object has no attribute 'poster'

# %%
dir(podcast)
# Out:
# ['DEFAULT_PREVIEW_MODES',
#  'DoesNotExist',
#  'EXPLICIT_CHOICES',
#  'Meta',
#  'MultipleObjectsReturned',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_column_name_clashes',
#  '_check_constraints',
#  '_check_db_table_comment',
#  '_check_default_pk',
#  '_check_draftstate_and_revision_mixins',
#  '_check_field_name_clashes',
#  '_check_fields',
#  '_check_id_field',
#  '_check_index_together',
#  '_check_indexes',
#  '_check_local_fields',
#  '_check_long_column_names',
#  '_check_m2m_through_same_relationship',
#  '_check_managers',
# ...
