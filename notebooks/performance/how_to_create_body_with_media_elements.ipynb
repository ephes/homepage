# %%
from rich import print as rprint

# %%
blog_slug = "das_claas_und_nora_blog"
blog = Blog.objects.get(slug=blog_slug)

# %%
post = blog.unfiltered_published_posts.get(slug="januar-2024-01-01")

# %%
post.slug
# Out:
# 'januar-2024-01-01'

# %%
rprint(post.body.raw_data)
# Out:
# [{'id': '8f43ae87-6be3-4dbc-924c-b9a3f71668d7', 'type': 'overview', 'value': [{'id':
# '5c06c677-e1a4-44ce-b91b-71fdb7940f28', 'type': 'paragraph', 'value': '<p data-block-key="vxtfk">Viel passiert in
# der letzten Woche. Da waren zunächst einmal die beiden Weihnachtstage:</p><ul><li data-block-key="6il1a"><a
# id="496" linktype="page">In Siegburg</a></li><li data-block-key="8g1lh"><a id="498" linktype="page">In
# Lohmar</a></li></ul><p data-block-key="f4576">Am zweiten Weihnachtstag sind wir dann noch zu Katharinas Tante Meike
# nach Wormersdorf gefahren und haben ihre Oma Anita besucht. Claas ist auch nicht die ganze Zeit auf dem Elch liegen
# geblieben.</p>'}, {'id': '71ce10f1-ce13-45f8-bf82-5a1aa2de3d39', 'type': 'image', 'value': 2257}, {'id':
# '78ab3ca3-e53d-4a4b-9bbc-f0c5aa4c0a38', 'type': 'paragraph', 'value': '<p data-block-key="ebqd7">Am Mittwoch sind
# wir mit Huan, Volker und Charlie ins <a href="https://www.jt-bonn.de/home/">Junge Theater in Bonn</a> gefahren und
# ...
